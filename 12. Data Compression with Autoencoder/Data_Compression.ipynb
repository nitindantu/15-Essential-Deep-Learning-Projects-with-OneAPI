# %%
from keras.layers import Input, Dense
from keras.models import Sequential

# Define the autoencoder architecture
input_dim = 784  # Input dimension
encoding_dim = 32  # Dimension of the encoded representation

# Create the autoencoder model
autoencoder = Sequential()

# Encoder layers
autoencoder.add(Dense(encoding_dim, activation='relu', input_shape=(input_dim,)))

# Decoder layers
autoencoder.add(Dense(input_dim, activation='sigmoid'))

# Compile the autoencoder
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Load and preprocess the data
# Assuming you have a dataset X with shape (num_samples, input_dim)
# Normalize the data between 0 and 1
X = np.random.rand(1000, input_dim)  # Replace with your actual data

# Train the autoencoder
autoencoder.fit(X, X, epochs=50, batch_size=32)

# Compress the data using the encoder
encoder = Sequential()
encoder.add(autoencoder.layers[0])  # Add the encoder layer
compressed_data = encoder.predict(X)

# Print the shape of the compressed data
print("Original Data Shape:", X.shape)
print("Compressed Data Shape:", compressed_data.shape)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 3ms/step - loss: 0.6933
# Epoch 2/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6931
# Epoch 3/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6931
# Epoch 4/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6931
# Epoch 5/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6931
# Epoch 6/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6930
# Epoch 7/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6930
# Epoch 8/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6930
# Epoch 9/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6930
# Epoch 10/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6930
# Epoch 11/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6930
# Epoch 12/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6930
# ...
